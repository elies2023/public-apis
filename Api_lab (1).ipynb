# %%
# Import requests library
import requests

burger= response = requests.get("https://bobsburgers-api.herokuapp.com/characters/?limit=9&skip=99")
print("burger:", burger.status_code)

# you_tube= requests.get("https://www.youtube.com/user/TheReportOfTheWeek")
# print("you_tube:", you_tube.status_code)
# Out:
# burger: 200

# %%
#print(burger)
print(burger.text)
# Out:
# [{"id":100,"name":"Critter","image":"https://bobsburgers-api.herokuapp.com/images/characters/100.jpg","age":"20s-30s","gender":"Male","hairColor":"Brown","relatives":[{"_id":"6422c22f928fca2484b4764a","name":"Sidecar","wikiUrl":"https://bobs-burgers.fandom.com/wiki/Sidecar","relationship":"son"},{"_id":"6422c22f928fca2484b4764b","name":"Mudflap","wikiUrl":"https://bobs-burgers.fandom.com/wiki/Mudflap","relationship":"wife","url":"https://bobsburgers-api.herokuapp.com/characters/352"}],"occupation":"Chapter president of the One Eyed Snakes/Employee at What the Tech","firstEpisode":"\"Ear-sy Rider\"","voicedBy":"Robert Ben Garant","url":"https://bobsburgers-api.herokuapp.com/characters/100","wikiUrl":"https://bobs-burgers.fandom.com/wiki/Critter"},{"id":101,"name":"Curt","image":"https://bobsburgers-api.herokuapp.com/images/characters/101.jpg","age":"13 (30 years ago), 43 (current)","gender":"Male","hairColor":"Brown","occupation":"Student at Buchannan Middle School (30 years ago)","fi
# ...

# %%
burger.text[3]
# Out:
# 'i'

# %%
import json

response = requests.get('https://bobsburgers-api.herokuapp.com/characters/?limit=9&skip=99')
#response
results = response.json()
results
# Out:
# [{'id': 100,
#   'name': 'Critter',
#   'image': 'https://bobsburgers-api.herokuapp.com/images/characters/100.jpg',
#   'age': '20s-30s',
#   'gender': 'Male',
#   'hairColor': 'Brown',
#   'relatives': [{'_id': '6422c314928fca2484b47652',
#     'name': 'Sidecar',
#     'wikiUrl': 'https://bobs-burgers.fandom.com/wiki/Sidecar',
#     'relationship': 'son'},
#    {'_id': '6422c314928fca2484b47653',
#     'name': 'Mudflap',
#     'wikiUrl': 'https://bobs-burgers.fandom.com/wiki/Mudflap',
#     'relationship': 'wife',
#     'url': 'https://bobsburgers-api.herokuapp.com/characters/352'}],
#   'occupation': 'Chapter president of the One Eyed Snakes/Employee at What the Tech',
#   'firstEpisode': '"Ear-sy Rider"',
#   'voicedBy': 'Robert Ben Garant',
#   'url': 'https://bobsburgers-api.herokuapp.com/characters/100',
#   'wikiUrl': 'https://bobs-burgers.fandom.com/wiki/Critter'},
#  {'id': 101,
#   'name': 'Curt',
# ...

# %%
import pandas as pd
pd.set_option("display.max_rows", 0)

data = pd.DataFrame(results)
data.head(10)
# Out:
#     id               name                                              image  \
# 0  100            Critter  https://bobsburgers-api.herokuapp.com/images/c...
# 1  101               Curt  https://bobsburgers-api.herokuapp.com/images/c...
# 2  102       Cynthia Bush  https://bobsburgers-api.herokuapp.com/images/c...
# 3  103             Dahlia  https://bobsburgers-api.herokuapp.com/images/c...
# 4  104   Dakota Applebaum  https://bobsburgers-api.herokuapp.com/images/c...
# 5  105     Dalton Crespin  https://bobsburgers-api.herokuapp.com/images/c...
# 6  106              Damon  https://bobsburgers-api.herokuapp.com/images/c...
# 7  107  Daniel Cunningham  https://bobsburgers-api.herokuapp.com/images/c...
# 8  108    Danny Duszynski  https://bobsburgers-api.herokuapp.com/images/c...
#
#                                age  gender      hairColor  \
# 0                          20s-30s    Male          Brown
# 1  13 (30 years ago), 43 (current)    Male          Brown
# ...

# %%
you_tube= requests.get("https://www.youtube.com/user/TheReportOfTheWeek")
print("you_tube:", you_tube.status_code)
# Out:
# you_tube: 200

# %%
#print(you_tube)
print(you_tube.text)
# Out:
# <!DOCTYPE html><html lang="de" dir="ltr"><head><style nonce="yOEKN_hPWrZRvWc0KcQEJw">
# a, a:link, a:visited, a:active, a:hover {
#   color: #1a73e8;
#   text-decoration: none;
# }
# body {
#   font-family: Roboto,RobotoDraft,Helvetica,Arial,sans-serif;
#   text-align: center;
#   -ms-text-size-adjust: 100%;
#   -moz-text-size-adjust: 100%;
#   -webkit-text-size-adjust: 100%;
# }
# .box {
#   border: 1px solid #dadce0;
#   box-sizing: border-box;
#   border-radius: 8px;
#   margin: 24px auto 5px auto;
#   max-width: 800px;
#   padding: 24px;
# }
# h1 {
#   color: #2c2c2c;
#   font-size: 24px;
#   hyphens: auto;
#   margin: 24px 0;
# }
# .icaCallout {
#   background-color: #f8f9fa;
#   padding: 12px 16px;
#   border-radius: 10px;
#   margin-bottom: 10px;
# }
# p, .sub, .contentText, .icaCallout {
#   color: #5f6368;;
#   font-size: 14px;
#   line-height: 20px;
#   letter-spacing: 0.2px;
#   text-align: left;
# }
# .signin {
#   text-align: right;
# }
# .saveButtonContainer,
# ...

# %%
import json

response = requests.get('https://www.youtube.com/user/TheReportOfTheWeek')
#response
results = response.json()
results
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_11972/1141718105.py in <module>
#       3 response = requests.get('https://www.youtube.com/user/TheReportOfTheWeek')
#       4 #response
# ----> 5 results = response.json()
#       6 results
#
# ~\anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     908                     # used.
#     909                     pass
# --> 910         return complexjson.loads(self.text, **kwargs)
#     911
#     912     @property
#
# ~\anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
# ...

# %%
you_tube.text[2]
# Out:
# 'D'

# %%
cat= response = requests.get("https://meowfacts.herokuapp.com/?count=5")
print("cat:", cat.status_code)
# Out:
# cat: 200

# %%
import json

response = requests.get("https://meowfacts.herokuapp.com/?count=5")
#response
results = response.json()
results
# Out:
# {'data': ['Cats can drink sea water in order to survive.',
#   'Cats have individual preferences for scratching surfaces and angles. Some are horizontal scratchers while others exercise their claws vertically.',
#   'Cats, especially older cats, do get cancer. Many times this disease can be treated successfully.',
#   'Cats do not think that they are little people. They think that we are big cats. This influences their behavior in many ways.',
#   "A cat's whiskers are thought to be a kind of radar, which helps a cat gauge the space it intends to walk through."]}

# %%
import pandas as pd
pd.set_option("display.max_rows", 0)

data = pd.DataFrame(results)
data.head(10)
# Out:
#                                                 data
# 0      Cats can drink sea water in order to survive.
# 1  Cats have individual preferences for scratchin...
# 2  Cats, especially older cats, do get cancer. Ma...
# 3  Cats do not think that they are little people....
# 4  A cat's whiskers are thought to be a kind of r...

# %%
google = requests.get("https://developers.google.com")
print("Google:", google.status_code)
# Out:
# Google: 200

# %%
#print(google)
print(google.text)
# Out:
# <!doctype html>
# <html
#       lang="en"
#       dir="ltr">
#   <head>
#     <meta name="google-signin-client-id" content="721724668570-nbkv1cfusk7kk4eni4pjvepaus73b13t.apps.googleusercontent.com">
#     <meta name="google-signin-scope"
#           content="profile email https://www.googleapis.com/auth/developerprofiles https://www.googleapis.com/auth/developerprofiles.award">
#     <meta property="og:site_name" content="Google Developers">
#     <meta property="og:type" content="website"><meta name="theme-color" content="#ffffff"><meta charset="utf-8">
#     <meta content="IE=Edge" http-equiv="X-UA-Compatible">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#
#
#     <link rel="manifest" href="/_pwa/developers/manifest.json"
#           crossorigin="use-credentials">
#     <link rel="preconnect" href="//www.gstatic.com" crossorigin>
#     <link rel="preconnect" href="//fonts.gstatic.com" crossorigin>
# ...

# %%
import json

response = requests.get('https://jsonplaceholder.typicode.com/todos')
#response
results = response.json()
results
# Out:
# [{'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False},
#  {'userId': 1,
#   'id': 2,
#   'title': 'quis ut nam facilis et officia qui',
#   'completed': False},
#  {'userId': 1, 'id': 3, 'title': 'fugiat veniam minus', 'completed': False},
#  {'userId': 1, 'id': 4, 'title': 'et porro tempora', 'completed': True},
#  {'userId': 1,
#   'id': 5,
#   'title': 'laboriosam mollitia et enim quasi adipisci quia provident illum',
#   'completed': False},
#  {'userId': 1,
#   'id': 6,
#   'title': 'qui ullam ratione quibusdam voluptatem quia omnis',
#   'completed': False},
#  {'userId': 1,
#   'id': 7,
#   'title': 'illo expedita consequatur quia in',
#   'completed': False},
#  {'userId': 1,
#   'id': 8,
#   'title': 'quo adipisci enim quam ut ab',
#   'completed': True},
#  {'userId': 1,
#   'id': 9,
#   'title': 'molestiae perspiciatis ipsa',
#   'completed': False},
#  {'userId': 1,
#   'id': 10,
#   'title': 'illo est ratione doloremque quia maiores aut',
# ...

# %%
import pandas as pd
pd.set_option("display.max_rows", 0)

data = pd.DataFrame(results)
data.head(10)
# Out:
#    userId  id                                              title  completed
# 0       1   1                                 delectus aut autem      False
# 1       1   2                 quis ut nam facilis et officia qui      False
# 2       1   3                                fugiat veniam minus      False
# 3       1   4                                   et porro tempora       True
# 4       1   5  laboriosam mollitia et enim quasi adipisci qui...      False
# 5       1   6  qui ullam ratione quibusdam voluptatem quia omnis      False
# 6       1   7                  illo expedita consequatur quia in      False
# 7       1   8                       quo adipisci enim quam ut ab       True
# 8       1   9                        molestiae perspiciatis ipsa      False
# 9       1  10       illo est ratione doloremque quia maiores aut       True

# %%
response = requests.get('https://api.github.com/events')

data = pd.DataFrame(response.json())
data.head()
#data.shape
# Out:
#             id               type  \
# 0  28029087669          PushEvent
# 1  28029087611          PushEvent
# 2  28029087690  IssueCommentEvent
# 3  28029087569   PullRequestEvent
# 4  28029087609  IssueCommentEvent
#
#                                                actor  \
# 0  {'id': 16837285, 'login': 'robodoo', 'display_...
# 1  {'id': 41898282, 'login': 'github-actions[bot]...
# 2  {'id': 49699333, 'login': 'dependabot[bot]', '...
# 3  {'id': 49699333, 'login': 'dependabot[bot]', '...
# 4  {'id': 41898282, 'login': 'github-actions[bot]...
#
#                                                 repo  \
# 0  {'id': 19745004, 'name': 'odoo/odoo', 'url': '...
# 1  {'id': 552933409, 'name': 'Eujosee/eujosee', '...
# 2  {'id': 259303274, 'name': 'ckomop0x/ckomop0x.m...
# 3  {'id': 618673955, 'name': 'agstar/halo-rust', ...
# 4  {'id': 260317971, 'name': 'module-federation/m...
#
#                                              payload  public  \
# ...

# %%
def flatten(data, col_list):
    for column in col_list:
        flattened = pd.DataFrame(dict(data[column])).transpose()
        columns = [str(col) for col in flattened.columns]
        flattened.columns = [column + '_' + colname for colname in columns]
        data = pd.concat([data, flattened], axis=1)
        data = data.drop(column, axis=1)
    return data

# %%
dict(data['actor'])
pd.DataFrame(dict(data['actor']))
pd.DataFrame(dict(data['actor'])).transpose()
# Out:
#            id                login      display_login gravatar_id  \
# 0    16837285              robodoo            robodoo
# 1    41898282  github-actions[bot]     github-actions
# 2    49699333      dependabot[bot]         dependabot
# 3    49699333      dependabot[bot]         dependabot
# 4    41898282  github-actions[bot]     github-actions
# 5    49699333      dependabot[bot]         dependabot
# 6    76484433        felixbarriere      felixbarriere
# 7    88290009             iamrk-js           iamrk-js
# 8    46001488               peta02             peta02
# 9   103327084    scalr-autotester0  scalr-autotester0
# 10   10514864        PabloMansanet      PabloMansanet
# 11   49699333      dependabot[bot]         dependabot
# ..        ...                  ...                ...         ...
# 18   12830755              ckousik            ckousik
# 19   41898282  github-actions[bot]     github-actions
# 20   10810283      direwolf-github    direwolf-github
# ...

# %%
nested_columns = ['actor', 'org', 'payload', 'repo']

flat = flatten(data, nested_columns)
flat
# Out:
#              id                           type  public            created_at  \
# 0   28029087669                      PushEvent    True  2023-03-28T11:08:21Z
# 1   28029087611                      PushEvent    True  2023-03-28T11:08:21Z
# 2   28029087690              IssueCommentEvent    True  2023-03-28T11:08:21Z
# 3   28029087569               PullRequestEvent    True  2023-03-28T11:08:21Z
# 4   28029087609              IssueCommentEvent    True  2023-03-28T11:08:21Z
# 5   28029087641               PullRequestEvent    True  2023-03-28T11:08:21Z
# 6   28029087656                      PushEvent    True  2023-03-28T11:08:21Z
# 7   28029087643                    CreateEvent    True  2023-03-28T11:08:21Z
# 8   28029087590                    CreateEvent    True  2023-03-28T11:08:21Z
# 9   28029087581                    CreateEvent    True  2023-03-28T11:08:21Z
# 10  28029087588                      PushEvent    True  2023-03-28T11:08:21Z
# ...
